# %% [markdown]
# # 🧩 Ejercicios de Herencia en Python
#
# En este cuaderno encontrarás **5 ejercicios** sobre **herencia** en Programación Orientada a Objetos.
#
# Cada ejercicio incluye:
# - Un enunciado con los atributos y métodos requeridos
# - Ejemplos de uso esperado en la sección **Prueba**
# - Una celda de código vacía donde debes escribir tu solución
#
# ---

# %% [markdown]
# ## 🚗 Ejercicio 1: Vehículos
#
# Crear tres clases que modelen vehículos usando herencia.
#
# ---
#
# ### Clase base: `Vehiculo`
#
# ## Atributos:
# - `marca`
# - `modelo`
# - `año`
# - `velocidad` (inicia en `0`)
#
# ## Métodos:
# - `acelerar(incremento)`: aumenta la velocidad. La velocidad no puede superar `200`
# - `frenar(decremento)`: disminuye la velocidad. La velocidad no puede bajar de `0`
# - `__str__`: retorna `"{marca} {modelo} ({año})"`
#
# ---
#
# ### Clase `Auto(Vehiculo)`:
#
# Hereda de `Vehiculo` y agrega:
#
# ## Atributos adicionales:
# - `numero_puertas`
# - `placa`: generada automáticamente al crear la instancia con 3 letras mayúsculas + 3 dígitos (usar `random`)
#
# ## Métodos:
# - Sobreescribir `__str__`: retorna `"{marca} {modelo} - Placa: {placa} - Puertas: {numero_puertas}"`
#
# ---
#
# ### Clase `Moto(Vehiculo)`:
#
# Hereda de `Vehiculo` y agrega:
#
# ## Atributos adicionales:
# - `tipo`: tipo de moto (ej: `'deportiva'`, `'crucero'`)
#
# ## Métodos:
# - `hacer_caballito()`: retorna `'¡Caballito!'` si `velocidad > 30`, de lo contrario `'Necesitas más velocidad'`
# - Sobreescribir `__str__`: retorna `"{marca} {modelo} - Tipo: {tipo}"`
#
# ---
#
# ## Prueba:
#
# ```python
# a = Auto('Toyota', 'Corolla', 2022, 4)
# print(a)              # Toyota Corolla - Placa: XYZ123 - Puertas: 4
# a.acelerar(80)
# print(a.velocidad)    # 80
# a.acelerar(200)
# print(a.velocidad)    # 200  ← no supera el máximo
#
# m = Moto('Honda', 'CBR', 2023, 'deportiva')
# m.acelerar(50)
# print(m.hacer_caballito())   # ¡Caballito!
# m.frenar(50)
# print(m.hacer_caballito())   # Necesitas más velocidad
# ```

# %%
# Escribe tu solución aquí
import random

# %% [markdown]
# ## 📐 Ejercicio 2: Figuras Geométricas
#
# Crear una jerarquía de clases para representar figuras geométricas.
#
# ---
#
# ### Clase base: `Figura`
#
# ## Atributos:
# - `color`
#
# ## Métodos:
# - `area()`: lanzar `NotImplementedError('Implementar en subclase')`
# - `perimetro()`: lanzar `NotImplementedError('Implementar en subclase')`
# - `__str__`: retorna `"Figura de color {color}"`
# - `descripcion()`: retorna `"Soy una {tipo} de color {color} con área {area:.2f} y perímetro {perimetro:.2f}"`, donde `tipo` es el nombre de la clase
#
# ---
#
# ### Clase `Circulo(Figura)`:
#
# ## Atributos adicionales:
# - `radio`
#
# ## Métodos:
# - `area()`: retorna $\pi \times r^2$
# - `perimetro()`: retorna $2 \times \pi \times r$
# - Sobreescribir `__str__`: retorna `"Círculo de radio {radio} y color {color}"`
#
# ---
#
# ### Clase `Triangulo(Figura)`:
#
# ## Atributos adicionales:
# - `base`, `altura`
# - `lado1`, `lado2`, `lado3`
#
# ## Métodos:
# - `area()`: retorna `(base × altura) / 2`
# - `perimetro()`: retorna la suma de los tres lados
# - Sobreescribir `__str__`: retorna `"Triángulo de base {base} y color {color}"`
#
# ---
#
# ## Prueba:
#
# ```python
# import math
#
# c = Circulo('rojo', 5)
# print(c)                    # Círculo de radio 5 y color rojo
# print(round(c.area(), 2))   # 78.54
# print(c.descripcion())      # Soy una Circulo de color rojo con área 78.54 y perímetro 31.42
#
# t = Triangulo('azul', 4, 3, 5, 4, 3)
# print(t.area())             # 6.0
# print(t.perimetro())        # 12
# print(t.descripcion())      # Soy una Triangulo de color azul con área 6.00 y perímetro 12.00
# ```

# %%
# Escribe tu solución aquí
import math

# %% [markdown]
# ## 💼 Ejercicio 3: Sistema de Empleados
#
# Crear una jerarquía de clases para manejar distintos tipos de empleados.
#
# ---
#
# ### Clase base: `Empleado`
#
# ## Atributos:
# - `nombre`
# - `id_empleado`: generado automáticamente con 2 letras mayúsculas + 4 dígitos (ej: `'AB1234'`)
#
# ## Métodos:
# - `calcular_salario()`: lanzar `NotImplementedError('Implementar en subclase')`
# - `__str__`: retorna `"Empleado: {nombre} | ID: {id_empleado}"`
#
# ---
#
# ### Clase `EmpleadoPorHoras(Empleado)`:
#
# ## Atributos adicionales:
# - `horas_trabajadas`
# - `tarifa_por_hora`
#
# ## Métodos:
# - `calcular_salario()`: retorna `horas_trabajadas × tarifa_por_hora`
# - Sobreescribir `__str__`: usar `super()` y agregar `" | {horas_trabajadas}h × ${tarifa_por_hora}/h"`
#
# ---
#
# ### Clase `Gerente(Empleado)`:
#
# ## Atributos adicionales:
# - `salario_base`
# - `bono_porcentaje`
#
# ## Métodos:
# - `calcular_salario()`: retorna `salario_base × (1 + bono_porcentaje / 100)`
# - `ascender(empleado, nuevo_salario_base)`: solo puede ascender a instancias de `Gerente`. Si la condición se cumple, modifica el `salario_base` del empleado y retorna un mensaje de confirmación. De lo contrario, retorna un mensaje de error
# - Sobreescribir `__str__`: usar `super()` y agregar `" | Salario base: ${salario_base}"`
#
# ---
#
# ## Prueba:
#
# ```python
# e = EmpleadoPorHoras('Laura', 160, 15000)
# print(e)                        # Empleado: Laura | ID: AB1234 | 160h × $15000/h
# print(e.calcular_salario())     # 2400000
#
# g = Gerente('Carlos', 5000000, 20)
# print(g)                        # Empleado: Carlos | ID: XY5678 | Salario base: $5000000
# print(g.calcular_salario())     # 6000000.0
#
# g2 = Gerente('Ana', 3000000, 10)
# print(g.ascender(g2, 4000000))  # Ana fue ascendida con nuevo salario base de 4000000
# print(g.ascender(e, 5000000))   # Solo se puede ascender a instancias de Gerente
# ```

# %%
# Escribe tu solución aquí
import random

# %% [markdown]
# ## 📚 Ejercicio 4: Pila con Historial
#
# Implementar una **pila** (estructura LIFO) y luego extenderla con registro de operaciones.
#
# ---
#
# ### Clase `Pila`:
#
# ## Atributos:
# - `_elementos`: lista interna que almacena los elementos (inicia vacía)
#
# ## Métodos:
# - `apilar(elemento)`: agrega el elemento al tope de la pila
# - `desapilar()`: elimina y retorna el elemento del tope. Si está vacía, lanzar `IndexError('La pila está vacía')`
# - `ver_tope()`: retorna el elemento del tope sin eliminarlo. Si está vacía, retornar `None`
# - `esta_vacia()`: retorna `True` si la pila no tiene elementos
# - `__len__`: retorna la cantidad de elementos
# - `__str__`: retorna `"Pila (tope → base): {elementos_de_tope_a_base}"`
#
# ---
#
# ### Clase `PilaConHistorial(Pila)`:
#
# Hereda de `Pila` y registra cada operación usando `super()`.
#
# ## Atributos adicionales:
# - `_historial`: lista de strings que describe cada operación (inicia vacía)
#
# ## Métodos:
# - Sobreescribir `apilar(elemento)`: llamar al método padre y registrar `'APILAR: {elemento}'`
# - Sobreescribir `desapilar()`: llamar al método padre y registrar `'DESAPILAR: {elemento}'`
# - `ver_historial()`: imprime cada operación del historial con su número
#
# ---
#
# ## Prueba:
#
# ```python
# p = PilaConHistorial()
# p.apilar(10)
# p.apilar(20)
# p.apilar(30)
# print(len(p))           # 3
# print(p.ver_tope())     # 30
# print(p.desapilar())    # 30
# print(p)                # Pila (tope → base): [20, 10]
# p.ver_historial()
# # 1. APILAR: 10
# # 2. APILAR: 20
# # 3. APILAR: 30
# # 4. DESAPILAR: 30
# ```

# %%
# Escribe tu solución aquí

# %% [markdown]
# ## 🔗 Ejercicio 5: Herencia Múltiple
#
# Crear un sistema de clases que combine herencia múltiple.
#
# ---
#
# ### Clase `Persona`:
#
# ## Atributos:
# - `nombre`
# - `edad`
#
# ## Métodos:
# - `presentarse()`: retorna `"Me llamo {nombre} y tengo {edad} años"`
# - `informacion()`: retorna `"Persona: {nombre}"`
#
# ---
#
# ### Clase `Trabajador`:
#
# ## Atributos:
# - `empresa`
# - `salario`
#
# ## Métodos:
# - `presentarse()`: retorna `"Trabajo en {empresa} con salario de ${salario}"`
# - `informacion()`: retorna `"Trabajador en: {empresa}"`
#
# ---
#
# ### Clase `EstudianteTrabajador(Persona, Trabajador)`:
#
# Hereda de **ambas** clases.
#
# ## Atributos:
# - Todos los de `Persona` y `Trabajador`
# - `universidad`
#
# ## Métodos:
# - `presentarse()`: combinar la información de ambas clases padre e incluir la universidad
# - `informacion()`: combinar la información de ambas clases padre e incluir la universidad
#
# ---
#
# ## Prueba:
#
# ```python
# et = EstudianteTrabajador('María', 22, 'TechCorp', 2000000, 'U. Externado')
# print(et.presentarse())
# # Me llamo María y tengo 22 años. Trabajo en TechCorp con salario de $2000000. Estudio en U. Externado
# print(et.informacion())
# # Persona: María | Trabajador en: TechCorp | Universidad: U. Externado
# print(isinstance(et, Persona))     # True
# print(isinstance(et, Trabajador))  # True
# print(EstudianteTrabajador.__mro__)
# ```
#
# ---
#
# ## Preguntas (responder en la celda Markdown de abajo):
#
# 1. ¿Cuál es el orden de resolución de métodos (`__mro__`) de `EstudianteTrabajador`?
# 2. ¿Toda instancia de `EstudianteTrabajador` es también instancia de `Persona`? ¿Y de `Trabajador`?
# 3. Si `EstudianteTrabajador` **no** sobreescribiera `presentarse()`, ¿de qué clase tomaría el método y por qué?

# %%
# Escribe tu solución aquí

# %% [markdown]
# ## Respuestas a las preguntas del Ejercicio 5
#
# 1.
#
# 2.
#
# 3.
