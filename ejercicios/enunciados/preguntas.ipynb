# %% [markdown]
# # 🧩 Ejercicios: Uso básico de métodos de instancia

# %% [markdown]
# ## Ejercicios 1
#
# Crear una clase `Persona` con:
#
# ## Atributos:
# - nombre
# - edad
#
# ## Métodos:
# - `saludar()`: imprime "Hola, soy {nombre}"
# - `es_mayor_de_edad()`: retorna `True` si edad >= 18, de lo contrario `False`
#
# ---
#
# ## Prueba:
#
# ```python
# p = Persona("Ana", 20)
#
# p.saludar()                 # Hola, soy Ana
# print(p.es_mayor_de_edad()) # True

# %% [markdown]
# ## 🧩 Ejercicio 2: Métodos que modifican el estado
#
# Crear una clase `Cuenta` con:
#
# ## Atributos:
# - titular
# - saldo
#
# ## Métodos:
# - `depositar(cantidad)`: aumenta el saldo
# - `retirar(cantidad)`: disminuye el saldo solo si hay suficiente dinero
# - `consultar_saldo()`: retorna el saldo actual
#
# ---
#
# ## Prueba:
#
# ```python
# c = Cuenta("Luis", 1000)
#
# c.depositar(500)
# c.retirar(300)
#
# print(c.consultar_saldo())  # 1200

# %% [markdown]
# ## 🧩 Ejercicio 3: Métodos con lógica
#
# Crear una clase `Rectangulo` con:
#
# ## Atributos:
# - base
# - altura
#
# ## Métodos:
# - `area()`: retorna el área
# - `perimetro()`: retorna el perímetro
# - `es_cuadrado()`: retorna `True` si base == altura
#
# ---
#
# ## Prueba:
#
# ```python
# r = Rectangulo(4, 4)
#
# print(r.area())        # 16
# print(r.perimetro())   # 16
# print(r.es_cuadrado()) # True

# %% [markdown]
# # 🧩 Ejercicios más interesantes

# %% [markdown]
# 1. Un polinomio es una expresión matemática de la forma:
#
# $$
# p(x) = a_n x^n + a_{n-1} x^{n-1} + \dots + a_1 x + a_0
# $$
#
# La clase `Polinomio` debe implementar los siguientes métodos:
#
# - `__init__(self, coeficientes)` Inicializa el polinomio como usted lo considere
#
# - `__str__(self)` Retorna una representación legible del polinomio.
#
# - `__add__(self, other)` Retorna la suma de dos polinomios.
#
# - `__sub__(self, other)` Retorna la resta de dos polinomios.
#
# - `__mul__(self, other)` Retorna la multiplicación de dos polinomios.
#
# - `evaluar(self, x)` Evalua el polinomio en el valor `x` y lo retorna

# %% [markdown]
# 2. Queremos implementar un cajero que inicie con billetes de denominación `10.000, 20.000, 50.000` y sea capaz de retornar la cantidad dada por un usuario
#
# La clase `cajero` tiene los siguiente métodos:
# - `__init__(self, n1, n2, n3)` Tiene la configuración inicial del cajero donde `ni` representa la cantidad de billetes del cajero
# - `retirar(self, cantidad)` Este método debe:
#     - Verificar que le puede retornar la cantidad indicada de dinero al usuario
#     - Actiualizar la cantidad de billetes dentro del cajero. Es decir actualizar sus atributos

# %% [markdown]
# # Taller 27 de abril

# %% [markdown]
# ## 🔹 Punto 1: Clase `Cuenta`
#
# Dicha cuenta debe recrear una cuenta bancaria básica que debe tener los siguientes métodos:
#
# - `__init__(self, titular, saldo)`: Dicha cuenta se inicia con un `titular` y un saldo inicial `saldo`
# - `depositar(self, cantidad)`: Permite depositar una `cantidad` y debe modificar el saldo. Nota: Asegurarse que la cantidad depositada sea un número positivo.
# - `retirar(self, cantidad)`: Permite retirar de la cuenta, pero debe asegurarse de tener los fondos suficientes y modificar el saldo.
# - `consultar_saldo(self)` : Permite ver el saldo de la cuenta
# - Reto final: ¿Cómo podemos asegurarnos de que el saldo inicial sea un número positivo al iniciar la clase?
#
# ## 🔹 Punto 2: Clase `VectoresR3`
#
# Dicha clase debe representar los vectores usuales en $\mathbb{R}^3$ y contener los siguientes métodos:
#
# - `__init__(self, L)`: Se inicia el vector con una lista de tres componentes
# - `__add__(self, v1)`: Para sumar dos vectores
# - `__rmul__(self, v1)`: Para recrear la multiplicación por escalar
# - `__sub__(self, v1)`: Para restar vectores
# - `producto_punto(self, v1)`: Para recrear el producto punto de dos vectores. Debe retornar un número.
# - `producto_cruz(self, v1)`: Para recrear el producto cruz de dos vectores. Debe retornar un vector
#
# ## 🔹 Punto 3: Clase `Cajero`
#
# Dicha clase representa un cajero con billetes de `10000, 20000, 50000` con los siguientes métodos.
#
# - `__init__(self, n1, n2, n5)`: La cantidad de billetes iniciales del cajero de cada denominación.
# - `retiro(self, x)` : Permite retirar una cantidad dada por el usuario. Debe asegurar que la cantidad solicitada sea un múltiplo de `10000` y asegurarse de que puede retornar la cantidad. En caso afirmativo debe actualizar los parametros de los billetes.
# - `consignacion(self, n1, n2, n5)`: El usuarion indica la cantidad de billetes de cada denominación que ingresa al cajero. Debe actualizar los atributos del cajero
# - `verificar_estado(self)` Retornar un mensaje con la cantidad de billetes de cada denominación.
#
# ## 🔹 Punto 4: Clase `Recta`:
#
# Dicha clase representa la recta en $\mathbb{R}^2$ que pasa por los puntos $(x1, y1), (x2, y2)$ en el formato $y = mx + b$. Queremos los siguientes métodos:
#
# - `__init__(self, x1, y1, x2, y2)` los valores iniciales
# - `pendiente(self)` Retorna la pendiente de la recta
# - `corte_eje_y(self)` Retorna el corte de la recta con el eje y
# - `__repr__(self)` Retorna el formato `y = mx + b`
# - `paralela(self, R1)` Retorna `True` si las recta es paralela a `R1`. La variable `R1` es una instancia de la clase `Recta`
# - `perpendicular(self, R1)` Retorna `True` si las recta es perpendicular a `R1`. La variable `R1` es una instancia de la clase `Recta`
# - El formato anterior solo permite representar rectas no verticales. ¿Cómo podemos asegurarnos que el usuario no introduzca datos que lleven a rectas de ese tipo?

# %% [markdown]
# ## Soluciones

# %%
class Cuenta:
    def __init__(self, titular, saldo):
        self.titular = titular
        self.saldo = saldo

    def depositar(self, cantidad):
        if cantidad < 0:
            return 'Cantidad no válida'
        self.saldo += cantidad
        #return self.consultar_saldo() # Esta linea retorna el saldo en cada deposito

    def retirar(self, cantidad):
        if self.saldo >= cantidad:
            self.saldo -= cantidad
            return 'Retiro exitoso'
        
        return 'Fondos insuficientes'
    
    def consultar_saldo(self):
        return f'Su saldo es {self.saldo}'

# %%
C1 = Cuenta('Arley', 1000)
C1.depositar(50000)

# %%
C1.consultar_saldo()
# Out:
# 'Su saldo es 51000'

# %%
C1.retirar(20000)
C1.consultar_saldo()
# Out:
# 'Su saldo es 31000'

# %% [markdown]
# # Ejercicios herencia

# %% [markdown]
# 1. En una lista de ejercicios anterior se pidio la clase `Polinomios`, por lo visto en clase lo mejor es inicializar los coeficientes en una lista. La idea de este ejercicio es realizar la clase de polinomios con una lista.
# Un polinomio es una expresión matemática de la forma
#
# $$
# p(x) = a_0 + a_1 x + \cdots + a_{n-1} x^{n-1} + a_n x^n
# $$
# y la lista que lo representa es
#
# $$
# L = [a_0, a_1, \cdots , a_{n-1}, a_n]
# $$
# Completar los métodos dados a continuación para crear la clase de `Polinomios`
#
# ```python
# class Polinomio:
#
#     def __init__(self, L):
#         """
#         Inicializa el polinomio con la lista de coeficientes.
#         """
#         self.L = L
#
#     def __str__(self):
#         """
#         Retorna una representación legible del polinomio.
#         """
#         pass
#
#     def __add__(self, other):
#         """
#         Retorna la suma de dos polinomios.
#         """
#         pass
#
#     def __sub__(self, other):
#         """
#         Retorna la resta de dos polinomios.
#         """
#         pass
#
#     def __mul__(self, other):
#         """
#         Retorna la multiplicación de dos polinomios.
#         """
#         pass
#
#     def evaluar(self, x):
#         """
#         Evalúa el polinomio en el valor x y lo retorna.
#         """
#         pass
# ```
# 2. La clase de arriba no permite derivar polinomios. Crear la clase `PolinomiosDerivables` que  herede de la clase de polinomis y además tenga los método adicionales:
#     - derivada(self): Retorna la derivada de un polinomio, el cual debe ser un elemento de la clase `PolinomiosDerivables`.
#     - recta_tangente(self, x): Retorna la recta tangente del polinomio en `x`. Dicho polinomio debe ser un un polinomio de la forma $p(x) = a + bx$ que es una instancia de la clase `PolinomiosDerivables`.
#     - grado(self): Retorna el grado del polinomio
#
#
# 3. Crear una clase `CuentaBancariaNU` que representa una cuenta bancaria básica. En la pantilla encuentraa los métodos con sus descripciones:
#
# ```python
# import random
#
# class CuentaBancariaNU:
#
#     def __init__(self, nombre, saldo_inicial=0):
#         """
#         Inicializa la cuenta con:
#         - nombre
#         - saldo inicial
#         - número de cuenta (4 letras + 4 dígitos)
#         """
#         self.nombre = nombre
#         self.saldo_inicial = saldo_inicial
#         self.numero_cuenta = # Utilizar el método generar_numero_cuenta
#
#     def generar_numero_cuenta(self):
#         """
#         Genera un número de cuenta con 4 letras mayúsculas
#         seguidas de 4 dígitos.
#         """
#         pass
#
#     def depositar(self, cantidad):
#         """
#         Aumenta el saldo en la cantidad indicada e imprime un aviso con el saldo
#         """
#         pass
#
#     def retirar(self, cantidad):
#         """
#         Disminuye el saldo si hay fondos suficientes e imprime un aviso con el saldo.
#         En caso de que no exista fondos suficientes le indica al usuario y termina el proceso.
#         """
#         pass
#
#     def __str__(self):
#         """
#         Retorna una representación de la cuenta con nombre, saldo
#         """
#         pass
# ```
# 4. La clase `CuentaCorrienteNU` es una extensión de `CuentaBancariaNU` en el cual al retirar el banco le presta hasta un monto de `10000`. Es decir, el banco le presta hasta diez mil pesos de más sobre su saldo y permite que este llegue hasta un tope negativo de `-10000`. Por ejemplo, si se tiene un saldo de `50000` el usuario podria retirar hasta `60000` y si tiene un saldo de `-500` podria retirar hasta `9500`. Además, permite transferir a cuentas de `CuentaBancaria` pero no de cuenta simple.
#
# ```python
# class CuentaAhorrosNU(CuentaBancariaNU):
#
#     def retirar(self, cantidad):
#         pass
#
#     def transferir(self, otra_cuenta, cantidad):
#         """
#         Permite transferir a otras instacias de `CuentaBancariaNU`. Actualizar los saldos correspondientes
#         Debe utilizar `isinstance`
#         """
#         pass
# ```
# 5. Algunas preguntas:
#     - ¿Toda instancia de `CuentaBancariaNu` es una instancia de `CuentaAhorrosNU`?
#     - ¿Toda instancia de `CuentaAhorrosNU` es una instancia de `CuentaBancariaNU`?
#     - ¿Sepuede transferir dinero entre instancias de `CuentaAhorrosNU`?
#     - ¿Cómo modificar el método transferir para que se acepten únicamente transferencias entre cuentas del tipo `CuentaAhorrosNU` pero no de `CuentaBancariaNU`?
